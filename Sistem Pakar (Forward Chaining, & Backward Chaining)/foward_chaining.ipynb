# %%
def foward_chaining(facts, rules):
    inferred = set(facts)
    changed = True

    while changed:
        changed = False
        for rule in rules:
            # Use inferred here
            if rule["if"].issubset(inferred) and rule["then"] not in inferred:
                inferred.add(rule["then"])
                changed = True
    return inferred #But you probably meant to return inferred here.

facts = {"has_wheels", "has_engine" ,"has_four_wheels"}
rules = [
    {"if": {"has_wheels", "has_engine"}, "then": "is_vehicle"},
    {"if": {"is_vehicle", "has_two_wheels"}, "then": "is_motorcycle"},
    {"if": {"is_vehicle", "has_four_wheels"}, "then": "is_Car"},
]


result = foward_chaining(facts, rules)
print("inferred facts:", result)
# Out:
# inferred facts: {'has_four_wheels', 'has_engine', 'has_wheels', 'is_Car', 'is_vehicle'}
