# %%
# !pip install experta
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for frozendict: filename=frozendict-1.2-py3-none-any.whl size=3149 sha256=218298426a55c48e7ee93e84224c4237fe7dd2dd4afc7f3a16047e4a42c7f9e0
#   Stored in directory: /root/.cache/pip/wheels/49/ac/f8/cb8120244e710bdb479c86198b03c7b08c3c2d3d2bf448fd6e
# Successfully built frozendict
# ...
#   Attempting uninstall: frozendict
#     Found existing installation: frozendict 2.4.6
#     Uninstalling frozendict-2.4.6:
#       Successfully uninstalled frozendict-2.4.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.55 requires frozendict>=2.3.4, but you have frozendict 1.2 which is incompatible.
# ...

# %%
# !pip install --upgrade frozendict
# Out:
# ...
#   Attempting uninstall: frozendict
#     Found existing installation: frozendict 1.2
#     Uninstalling frozendict-1.2:
#       Successfully uninstalled frozendict-1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# experta 1.9.4 requires frozendict==1.2, but you have frozendict 2.4.6 which is incompatible.
# ...

# %%
from experta import *

class Diagnosis(KnowledgeEngine):

    @Rule(Fact(cough=True) & Fact(fever=True) & Fact(fatigue=True))
    def flu(self):
        print("Diagnosis: You may have Flu.")

    @Rule(Fact(cough=True) & Fact(fever=True) & Fact(brething_difficulty=True))
    def pneumonia(self):
        print("Diagnosis: You may have Pneumonia.")

    @Rule(Fact(sneezing=True) & Fact(runny_nose=True) & Fact(cough=False))
    def cold(self):
        print("Diagnosis: You may have a common Cold.")

    @Rule(Fact(sore_throat=True) & Fact(fever=True))
    def throat_infection(self):
        print("Diagnosis: You may have a Throat Infection.")

    @Rule(Fact(cough=False) & Fact(fever=False) & Fact(fatigue=False))
    def healthy(self):
        print("Diagnosis: You seem to be healthy.")

    # Tambahan penyakit baru

    @Rule(Fact(fever=True) & Fact(rash=True) & Fact(headache=True))
    def dengue(self):
        print("Diagnosis: You may have Dengue Fever.")

    @Rule(Fact(fever=True) & Fact(nausea=True) & Fact(vomiting=True))
    def typhoid(self):
        print("Diagnosis: You may have Typhoid Fever.")

    @Rule(Fact(brething_difficulty=True) & Fact(chest_pain=True) & Fact(cough=True))
    def asthma(self):
        print("Diagnosis: You may have Asthma.")

    @Rule(Fact(headache=True) & Fact(nausea=True) & Fact(sensitivity_to_light=True))
    def migraine(self):
        print("Diagnosis: You may have a Migraine.")


def get_input():
    """Helper function to get user input as boolean (yes/no)."""
    def ask_question(question):
        return input(question + " (yes/no): ").strip().lower() == "yes"

    return {
        "cough": ask_question("Do you have a cough?"),
        "fever": ask_question("Do you have a fever?"),
        "fatigue": ask_question("Do you feel fatigued?"),
        "brething_difficulty": ask_question("Do you have difficulty breathing?"),
        "sneezing": ask_question("Do you have sneezing?"),
        "runny_nose": ask_question("Do you have a runny nose?"),
        "sore_throat": ask_question("Do you have a sore throat?"),
        # Tambahan gejala untuk penyakit baru
        "rash": ask_question("Do you have a skin rash?"),
        "headache": ask_question("Do you have a headache?"),
        "nausea": ask_question("Do you feel nauseous?"),
        "vomiting": ask_question("Do you have vomiting?"),
        "chest_pain": ask_question("Do you feel chest pain?"),
        "sensitivity_to_light": ask_question("Are you sensitive to light?")
    }


if __name__ == "__main__":
    symptoms = get_input()
    engine = Diagnosis()
    engine.reset()

    for symptom, present in symptoms.items():
        engine.declare(Fact(**{symptom: present}))

    engine.run()
# Out:
# Do you have a cough? (yes/no): no
# Do you have a fever? (yes/no): no
# Do you feel fatigued? (yes/no): no
# Do you have difficulty breathing? (yes/no): no
# Do you have sneezing? (yes/no): no
# Do you have a runny nose? (yes/no): no
# Do you have a sore throat? (yes/no): no
# Do you have a skin rash? (yes/no): no
# Do you have a headache? (yes/no): yes
# Do you feel nauseous? (yes/no): yes
# Do you have vomiting? (yes/no): no
# Do you feel chest pain? (yes/no): no
# Are you sensitive to light? (yes/no): yes
# Diagnosis: You may have a Migraine.
# Diagnosis: You seem to be healthy.
